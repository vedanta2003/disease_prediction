# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hospitals = pd.read_csv("/Users/vedanta/Documents/VSCode/hack_x/hospitals.csv")

# %%
hospitals.head()
# Out:
#                       Facility.Name Facility.City Facility.State  \
# 0  Southeast Alabama Medical Center        Dothan             AL
# 1     Marshall Medical Center South          Boaz             AL
# 2    Eliza Coffee Memorial Hospital      Florence             AL
# 3          Mizell Memorial Hospital           Opp             AL
# 4       Crenshaw Community Hospital       Luverne             AL
#
#   Facility.Type  Rating.Overall Rating.Mortality Rating.Safety  \
# 0    Government               2            Below         Above
# 1    Government               1            Below         Below
# 2    Government               3            Below         Above
# 3       Private               1             Same          Same
# 4   Proprietary               4             Same           NaN
#
#   Rating.Readmission Rating.Experience Rating.Effectiveness  ...  \
# 0              Below             Below                 Same  ...
# ...

# %%
columns_to_drop = ["Procedure.Heart Attack.Cost","Procedure.Heart Attack.Quality","Procedure.Heart Attack.Value","Procedure.Heart Failure.Cost","Procedure.Heart Failure.Quality","Procedure.Heart Failure.Value","Procedure.Pneumonia.Cost","Procedure.Pneumonia.Quality","Procedure.Pneumonia.Value","Procedure.Hip Knee.Cost","Procedure.Hip Knee.Quality","Procedure.Hip Knee.Value"]
hospitals.drop(columns_to_drop, axis=1, inplace=True)

# %%
hospitals.to_csv("newhospitals.csv")

# %%
df = pd.read_csv('/Users/vedanta/Documents/VSCode/hack_x/symptom_Description.csv')

# %%
df
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
df['Disease'].values
# Out:
# array(['Drug Reaction', 'Malaria', 'Allergy', 'Hypothyroidism',
#        'Psoriasis', 'GERD', 'Chronic cholestasis', 'hepatitis A',
#        'Osteoarthristis', '(vertigo) Paroymsal  Positional Vertigo',
#        'Hypoglycemia', 'Acne', 'Diabetes', 'Impetigo', 'Hypertension',
#        'Peptic ulcer diseae', 'Dimorphic hemorrhoids(piles)',
#        'Common Cold', 'Chicken pox', 'Cervical spondylosis',
#        'Hyperthyroidism', 'Urinary tract infection', 'Varicose veins',
#        'AIDS', 'Paralysis (brain hemorrhage)', 'Typhoid', 'Hepatitis B',
#        'Fungal infection', 'Hepatitis C', 'Migraine', 'Bronchial Asthma',
#        'Alcoholic hepatitis', 'Jaundice', 'Hepatitis E', 'Dengue',
#        'Hepatitis D', 'Heart attack', 'Pneumonia', 'Arthritis',
#        'Gastroenteritis', 'Tuberculosis'], dtype=object)

# %%
df = df.drop(columns={'Description','weight'})

# %%
severity_scores = {
    'Drug Reaction': 2, 'Malaria': 3, 'Allergy': 2, 'Hypothyroidism': 2, 'Psoriasis': 3,
    'GERD': 2, 'Chronic cholestasis': 4, 'hepatitis A': 3, 'Osteoarthristis': 4,
    '(vertigo) Paroymsal Positional Vertigo': 2, 'Hypoglycemia': 3, 'Acne': 1, 'Diabetes': 4,
    'Impetigo': 2, 'Hypertension': 3, 'Peptic ulcer diseae': 3, 'Dimorphic hemorrhoids(piles)': 2,
    'Common Cold': 1, 'Chicken pox': 2, 'Cervical spondylosis': 4, 'Hyperthyroidism': 3,
    'Urinary tract infection': 2, 'Varicose veins': 2, 'AIDS': 5, 'Paralysis (brain hemorrhage)': 4,
    'Typhoid': 3, 'Hepatitis B': 4, 'Fungal infection': 2, 'Hepatitis C': 4, 'Migraine': 3,
    'Bronchial Asthma': 3, 'Alcoholic hepatitis': 4, 'Jaundice': 3, 'Hepatitis E': 3,
    'Dengue': 3, 'Hepatitis D': 4, 'Heart attack': 5, 'Pneumonia': 4, 'Arthritis': 4,
    'Gastroenteritis': 3, 'Tuberculosis': 4
}

# Add the severity scores to the DataFrame
df['Severity'] = df['Disease'].map(severity_scores)

# Display the DataFrame with severity scores
print(df)
# Out:
#                                     Disease  Severity
# 0                             Drug Reaction       2.0
# 1                                   Malaria       3.0
# 2                                   Allergy       2.0
# 3                            Hypothyroidism       2.0
# 4                                 Psoriasis       3.0
# 5                                      GERD       2.0
# 6                       Chronic cholestasis       4.0
# 7                               hepatitis A       3.0
# 8                           Osteoarthristis       4.0
# 9   (vertigo) Paroymsal  Positional Vertigo       NaN
# 10                             Hypoglycemia       3.0
# 11                                     Acne       1.0
# 12                                 Diabetes       4.0
# 13                                 Impetigo       2.0
# 14                             Hypertension       3.0
# 15                      Peptic ulcer diseae       3.0
# ...

# %%
df.to_csv("disease_severity.csv")

# %%
# Out:
# array([[1, 2, 2, 3]])
